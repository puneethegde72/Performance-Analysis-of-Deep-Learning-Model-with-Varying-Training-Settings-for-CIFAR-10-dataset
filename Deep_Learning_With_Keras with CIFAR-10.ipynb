# %% [markdown]
# <a href="https://colab.research.google.com/github/puneethegde72/Performance-Analysis-of-Deep-Learning-Model-with-Varying-Training-Settings-for-CIFAR-10-dataset/blob/main/Deep_Learning_With_Keras%20with%20CIFAR-10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment 1 - Deep Learning With Keras - 40%
#
# **IMPORTANT NOTE**: By default, this notebook is set to a CPU runtime, to help prevent you getting locked out of Google Colab. When training your models, you will need to switch to a GPU runtime, otherwise the training will take a very long time.
#
# **Deadline**: 21 Mar 2023, 23:59
#
# **Submission Requirements**: You should submit your Colab Notebook, with all the outputs printed, and a sharing link to the notebook in your Drive. As detailed above, you should submit a 2-page report in PDF or DOCX format.
#
# **Learning Outcomes**
#
# This Assignment assesses the following module Learning Outcomes (from Definitive Module Document):
#
# * have knowledge of and understand how GPUs can accelerate data processing
# * be able to write data processing pipelines that exploit Tensorflow
# * have knowledge of and understand how to develop GPU-accelerated data processing pipelines using the Tensorflow and RAPIDS frameworks
#
# **Assignment Details**
#
# This assignment will test your ability to implement and test a deep neural network using keras. By varying the properties of the model and the data input pipeline, you will explore and analyse the training time and performance of the model. There will be four tasks for you to complete, each of which requires you to complete a range of tests on the model, visualise the results, and comment on them in a short report. Your report should focus on explaining and critically analysing the results—you will be assessed not just on your ability to show what is happening, but explain WHY it is happening.
#
# All coding work for this assignment should be done inside a copy of the Colab Notebook provided on this page. Any submissions not in this format will not be marked.
#
# **Task 1**: A model description is provided in the Colab Notebook for this assignment. Implement this model, ensuring that you have the correct output shapes for each of the layers and the correct number of model parameters. Train the model on the dataset provided in the notebook—initial training settings are provided also. Create plots of the losses and metrics of the training and validation data, and a plot that shows example images from each class that have been correctly AND incorrectly labelled by the model. Analyse these results in your report.
#
# **Task 2**: Select two additional optimizers. Including the one provided in the initial training settings, test your model with each of these optimizers using a range of different learning rates. You may need to train the model for more epochs to ensure that it converges on a solution. Create plots that show the losses and metrics for each of these runs, and comment on the results in your report. Select the optimizer and learning rate that provided the best results, and move onto the next task.
#
# **Task 3**: The batch size can heavily influence the amount of time it takes to train a model. Vary the batch size used to train the model and, utilising the Early Stopping callback provided, create plots that show how the time per epoch and total training time changes. Comment on these results in your report.
#
# **Task 4**: The model as provided does not contain any regularisation techniques. Edit the model architecture to include at least two examples of regularisation. Retrain the model using the new architecture, and repeat the analysis performed in task 1. In your report, compare and contrast the results from this task, with those from the initial model configuration.

# %%
# Module Imports - Add any additional modules here
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow.keras import layers, models, optimizers, losses, callbacks,\
                             regularizers
from keras.engine.input_layer import Input
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping

# %%
# Loading the Dataset. Here we use the CIFAR-10 dataset of labelled images

(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

# Rescale the pixel values
x_train = x_train/255.
x_test = x_test/255.

# List of label names
class_names = ['plane', 'car', 'bird', 'cat', 'deer',
               'canine', 'frog', 'horse', 'boat', 'truck']
y_train_labels_onehot_encode= to_categorical(y_train)
y_test_labels_onehot_encode= to_categorical(y_test)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 51s 0us/step

# %% [markdown]
# # Task 1 - Initial Model
#
# Implement the model architecture detailed below, using the Keras Functional API, ensuring that you have the correct output shapes for each of the layers.
#
# Train the model on the CIFAR-10 dataset.
#
# Create plots of the losses and metrics of the training and validation data, and plots that show example test images from each class that have been correctly AND incorrectly labelled by the model.
#
# Analyse these results in your report.
#
# **Model Architecture**
#
# A summary of the model architecture is given here, which shows the layers of the model, the output shapes of those layers, and the activation functions used. You will need to work out the other settings used to produce the model, such as the kernal sizes, padding schemes, and stride lengths. You should ensure that the output shapes and total number of parameters in your model match the summary here.
#
# ```
# Model: "cifar_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Activation
# =================================================================
#  Input (InputLayer)          [(None, 32, 32, 3)]       None
#
#  conv_1 (Conv2D)             (None, 32, 32, 16)        ReLU
#
#  conv_2 (Conv2D)             (None, 32, 32, 16)        ReLU
#
#  pool_1 (MaxPooling2D)       (None, 16, 16, 16)        None
#
#  conv_3 (Conv2D)             (None, 16, 16, 32)        ReLU
#
#  conv_4 (Conv2D)             (None, 16, 16, 32)        ReLU
#
#  pool_2 (MaxPooling2D)       (None, 8, 8, 32)          None
#
#  conv_5 (Conv2D)             (None, 8, 8, 64)          ReLU
#
#  conv_6 (Conv2D)             (None, 8, 8, 64)          ReLU
#
#  pool_3 (MaxPooling2D)       (None, 4, 4, 64)          None
#
#  flat (Flatten)              (None, 1024)              None
#
#  fc_1 (Dense)                (None, 512)               ReLU
#
#  Output (Dense)              (None, 10)                SoftMax
#
# =================================================================
# Total params: 602,010
# Trainable params: 602,010
# Non-trainable params: 0
# _________________________________________________________________
# ```

# %%
### Create  e model using the provided architecture
input= layers.Input((32, 32, 3), dtype='float32', name='Model_Input')
conv_1 = layers.Conv2D(16, (3, 3), activation='relu',
                      padding='same', name='conv_1')(input)
conv_2 = layers.Conv2D(16, (3, 3) , activation='relu',
                      padding='same', name='conv_2')(conv_1)
pool_1 = layers.MaxPooling2D((2, 2),padding='same', 
                             name='pool_1')(conv_2)
conv_3 = layers.Conv2D(32, (3, 3) , activation='relu',
                      padding='same', name='conv_3')(pool_1)

conv_4 = layers.Conv2D(32, (3, 3) , activation='relu',
                      padding='same', name='conv_4')(conv_3)
pool_2 = layers.MaxPooling2D((2, 2),padding='same', 
                             name='pool_2')(conv_4)

conv_5 = layers.Conv2D(64,(3, 3), activation='relu',
                      padding='same', name='conv_5')(pool_2)
conv_6 = layers.Conv2D(64,(3, 3), activation='relu',
                      padding='same', name='conv_6')(conv_5)
pool_3 = layers.MaxPooling2D((2, 2),padding='same', 
                             name='pool_3')(conv_6)
flat = layers.Flatten()(pool_3)

fc_1 = layers.Dense(512, activation='relu')(flat)
Output = layers.Dense(10, activation='softmax')(fc_1)

cifar_model = models.Model(inputs= input, outputs = Output)

dot_img_file = '/tmp/model_1.png'
tf.keras.utils.plot_model(cifar_model, to_file=dot_img_file, show_shapes=True)

# %%
cifar_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Model_Input (InputLayer)    [(None, 32, 32, 3)]       0
#
#  conv_1 (Conv2D)             (None, 32, 32, 16)        448
#
#  conv_2 (Conv2D)             (None, 32, 32, 16)        2320
#
#  pool_1 (MaxPooling2D)       (None, 16, 16, 16)        0
#
#  conv_3 (Conv2D)             (None, 16, 16, 32)        4640
#
#  conv_4 (Conv2D)             (None, 16, 16, 32)        9248
#
#  pool_2 (MaxPooling2D)       (None, 8, 8, 32)          0
#
#  conv_5 (Conv2D)             (None, 8, 8, 64)          18496
#
#  conv_6 (Conv2D)             (None, 8, 8, 64)          36928
#
#  pool_3 (MaxPooling2D)       (None, 4, 4, 64)          0
#
#  flatten (Flatten)           (None, 1024)              0
#
#  dense (Dense)               (None, 512)               524800
#
#  dense_1 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 602,010
# Trainable params: 602,010
# Non-trainable params: 0
# _________________________________________________________________

# %%
### Compile the model using the SGC optimizer, with default learning rate,
### Sparse Categorical Crossentropy, and accuracy metric.

cifar_model.compile(optimizer=optimizers.SGD(), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
### Train the model for 50 epochs, with a batch size of 128. Include the test
### data for model validation. Store the losses and metrics in a history object.
#history = cifar_model.fit(x= x_train,y= y_train, batch_size=128, epochs=50,
                          #validation_data=(x_test, y_test))
history = cifar_model.fit(x_train, y_train, batch_size=128, epochs=50, validation_data=(x_test, y_test))
# Out:
# Epoch 1/50
# 391/391 [==============================] - 14s 11ms/step - loss: 2.2983 - accuracy: 0.1050 - val_loss: 2.2885 - val_accuracy: 0.1080
# Epoch 2/50
# 391/391 [==============================] - 3s 8ms/step - loss: 2.2034 - accuracy: 0.1791 - val_loss: 2.1879 - val_accuracy: 0.1943
# Epoch 3/50
# 391/391 [==============================] - 3s 8ms/step - loss: 2.0029 - accuracy: 0.2758 - val_loss: 1.9154 - val_accuracy: 0.3069
# Epoch 4/50
# 391/391 [==============================] - 3s 8ms/step - loss: 1.8856 - accuracy: 0.3249 - val_loss: 1.7668 - val_accuracy: 0.3671
# Epoch 5/50
# 391/391 [==============================] - 4s 9ms/step - loss: 1.7638 - accuracy: 0.3724 - val_loss: 1.6695 - val_accuracy: 0.4062
# Epoch 6/50
# 391/391 [==============================] - 3s 8ms/step - loss: 1.6610 - accuracy: 0.4098 - val_loss: 1.6208 - val_accuracy: 0.4160
# Epoch 7/50
# 391/391 [==============================] - 3s 8ms/step - loss: 1.5845 - accuracy: 0.4380 - val_loss: 1.5604 - val_accuracy: 0.4424
# Epoch 8/50
# 391/391 [==============================] - 3s 8ms/step - loss: 1.5243 - accuracy: 0.4588 - val_loss: 1.5250 - val_accuracy: 0.4594
# Epoch 9/50
# 391/391 [==============================] - 4s 9ms/step - loss: 1.4651 - accuracy: 0.4790 - val_loss: 1.6607 - val_accuracy: 0.4169
# Epoch 10/50
# 391/391 [==============================] - 3s 8ms/step - loss: 1.4204 - accuracy: 0.4959 - val_loss: 1.3894 - val_accuracy: 0.5058
# Epoch 11/50
# 391/391 [==============================] - 3s 8ms/step - loss: 1.3855 - accuracy: 0.5073 - val_loss: 1.3797 - val_accuracy: 0.5050
# Epoch 12/50
# 391/391 [==============================] - 3s 8ms/step - loss: 1.3415 - accuracy: 0.5249 - val_loss: 1.3664 - val_accuracy: 0.5130
# Epoch 13/50
# 391/391 [==============================] - 3s 9ms/step - loss: 1.3063 - accuracy: 0.5383 - val_loss: 1.3135 - val_accuracy: 0.5413
# Epoch 14/50
# 391/391 [==============================] - 3s 8ms/step - loss: 1.2740 - accuracy: 0.5527 - val_loss: 1.2888 - val_accuracy: 0.5437
# Epoch 15/50
# 391/391 [==============================] - 3s 8ms/step - loss: 1.2434 - accuracy: 0.5584 - val_loss: 1.3179 - val_accuracy: 0.5297
# Epoch 16/50
# 391/391 [==============================] - 3s 8ms/step - loss: 1.2131 - accuracy: 0.5716 - val_loss: 1.2477 - val_accuracy: 0.5585
# Epoch 17/50
# 391/391 [==============================] - 3s 9ms/step - loss: 1.1805 - accuracy: 0.5817 - val_loss: 1.2347 - val_accuracy: 0.5706
# Epoch 18/50
# 391/391 [==============================] - 3s 8ms/step - loss: 1.1531 - accuracy: 0.5921 - val_loss: 1.2116 - val_accuracy: 0.5754
# Epoch 19/50
# 391/391 [==============================] - 3s 8ms/step - loss: 1.1218 - accuracy: 0.6038 - val_loss: 1.2428 - val_accuracy: 0.5662
# Epoch 20/50
# 391/391 [==============================] - 3s 9ms/step - loss: 1.0894 - accuracy: 0.6143 - val_loss: 1.2229 - val_accuracy: 0.5759
# Epoch 21/50
# 391/391 [==============================] - 3s 9ms/step - loss: 1.0691 - accuracy: 0.6215 - val_loss: 1.1807 - val_accuracy: 0.5879
# Epoch 22/50
# 391/391 [==============================] - 3s 8ms/step - loss: 1.0358 - accuracy: 0.6360 - val_loss: 1.2357 - val_accuracy: 0.5638
# Epoch 23/50
# 391/391 [==============================] - 3s 8ms/step - loss: 1.0116 - accuracy: 0.6452 - val_loss: 1.1560 - val_accuracy: 0.5974
# Epoch 24/50
# 391/391 [==============================] - 3s 9ms/step - loss: 0.9820 - accuracy: 0.6544 - val_loss: 1.1562 - val_accuracy: 0.5972
# Epoch 25/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.9536 - accuracy: 0.6643 - val_loss: 1.1606 - val_accuracy: 0.5992
# Epoch 26/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.9241 - accuracy: 0.6757 - val_loss: 1.2094 - val_accuracy: 0.5871
# Epoch 27/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.9016 - accuracy: 0.6835 - val_loss: 1.2276 - val_accuracy: 0.5791
# Epoch 28/50
# 391/391 [==============================] - 4s 10ms/step - loss: 0.8773 - accuracy: 0.6929 - val_loss: 1.1407 - val_accuracy: 0.6094
# Epoch 29/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.8471 - accuracy: 0.7019 - val_loss: 1.1617 - val_accuracy: 0.6062
# Epoch 30/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.8197 - accuracy: 0.7136 - val_loss: 1.2078 - val_accuracy: 0.5974
# Epoch 31/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.7908 - accuracy: 0.7237 - val_loss: 1.2128 - val_accuracy: 0.5934
# Epoch 32/50
# 391/391 [==============================] - 4s 9ms/step - loss: 0.7685 - accuracy: 0.7309 - val_loss: 1.1848 - val_accuracy: 0.6064
# Epoch 33/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.7374 - accuracy: 0.7422 - val_loss: 1.2587 - val_accuracy: 0.5837
# Epoch 34/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.7116 - accuracy: 0.7528 - val_loss: 1.1445 - val_accuracy: 0.6188
# Epoch 35/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.6874 - accuracy: 0.7624 - val_loss: 1.1927 - val_accuracy: 0.6157
# Epoch 36/50
# 391/391 [==============================] - 4s 9ms/step - loss: 0.6662 - accuracy: 0.7671 - val_loss: 1.1626 - val_accuracy: 0.6251
# Epoch 37/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.6306 - accuracy: 0.7825 - val_loss: 1.2113 - val_accuracy: 0.6179
# Epoch 38/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.6060 - accuracy: 0.7893 - val_loss: 1.2870 - val_accuracy: 0.6128
# Epoch 39/50
# 391/391 [==============================] - 3s 9ms/step - loss: 0.5826 - accuracy: 0.7967 - val_loss: 1.2782 - val_accuracy: 0.6102
# Epoch 40/50
# 391/391 [==============================] - 3s 9ms/step - loss: 0.5587 - accuracy: 0.8054 - val_loss: 1.2884 - val_accuracy: 0.6079
# Epoch 41/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.5280 - accuracy: 0.8149 - val_loss: 1.2981 - val_accuracy: 0.6187
# Epoch 42/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.5024 - accuracy: 0.8246 - val_loss: 1.3757 - val_accuracy: 0.6077
# Epoch 43/50
# 391/391 [==============================] - 3s 9ms/step - loss: 0.4727 - accuracy: 0.8337 - val_loss: 1.5858 - val_accuracy: 0.5736
# Epoch 44/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.4506 - accuracy: 0.8423 - val_loss: 1.4051 - val_accuracy: 0.6207
# Epoch 45/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.4234 - accuracy: 0.8514 - val_loss: 1.5219 - val_accuracy: 0.6072
# Epoch 46/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.3958 - accuracy: 0.8608 - val_loss: 1.6122 - val_accuracy: 0.5994
# Epoch 47/50
# 391/391 [==============================] - 4s 9ms/step - loss: 0.3750 - accuracy: 0.8670 - val_loss: 1.4863 - val_accuracy: 0.6191
# Epoch 48/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.3525 - accuracy: 0.8768 - val_loss: 1.4781 - val_accuracy: 0.6220
# Epoch 49/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.3253 - accuracy: 0.8867 - val_loss: 1.5828 - val_accuracy: 0.6197
# Epoch 50/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.2976 - accuracy: 0.8956 - val_loss: 1.7877 - val_accuracy: 0.6057

# %%
### Create plots of the losses and metrics of the training and validation data,
### and plots that shows example test images from each class that have been
### correctly AND incorrectly labelled by the model.

# Plot the training and validation losses
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Plot the training and validation accuracies
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()


# Get predicted classifications of test set images
y_pred1 = cifar_model.predict(x_test)
y_pred_classes1 = np.argmax(y_pred1, axis=1)

# Plot sample of test set images and their predicted classifications
fig, axs = plt.subplots(5, 5, figsize=(10, 10))
fig.suptitle('Sample of Test Set Images and Predicted Classifications')
for i in range(5):
    for j in range(5):
        index = i * 5 + j
        axs[i, j].imshow(x_test[index])
        axs[i, j].set_title(f"Predicted: {class_names[y_pred_classes1[index]]}")
        axs[i, j].axis('off')
plt.show()
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %% [markdown]
# # Task 2 - Testing Optimizers
#
# Select two additional optimizers. Including the SGD algorithm already used, test all three of these optimizers with a range of different learning rates.
#
# You may need to train the model for more or less epochs to ensure that it converges on a solution.
#
# Create plots that show the losses and metrics for each of these runs, and comment on the results in your report.
#
# Select the optimizer and learning rate that provided the best results, and move onto the next task.
#
# **Note**: You should reset the weights of the model between each test. A function is provided to perform this task. Store the losses and metrics of each run under a different variable name, so that they can all be plotted together.

# %%
# Utility function that resets the weights of your model. Call this before
# recompiling your model with updated settings, to ensure you train the model
# from scratch.

def reinitialize(model):
    # Loop over the layers of the model
    for l in model.layers:
        # Check if the layer has initializers
        if hasattr(l,"kernel_initializer"):
            # Reset the kernel weights
            l.kernel.assign(l.kernel_initializer(tf.shape(l.kernel)))
        if hasattr(l,"bias_initializer"):
            # Reset the bias
            l.bias.assign(l.bias_initializer(tf.shape(l.bias)))

# Function modified from here: https://stackoverflow.com/questions/63435679/reset-all-weights-of-keras-model

# %%
### Test the SGD Optimizer, plus two others of your choice, with a range of
### learning rates.
learning_rates = [0.001,0.0001,0.00001]
sgd_histories = []
adam_histories = []
rmsprop_histories = []
for lr in learning_rates:
  reinitialize(cifar_model)
  #SGD
  cifar_model.compile(optimizer=optimizers.SGD(learning_rate=lr), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
  history = cifar_model.fit(x_train, y_train, batch_size=128, epochs=25, validation_data=(x_test, y_test))
  sgd_histories.append(history)
  #ADAM
  cifar_model.compile(optimizer=optimizers.Adam(learning_rate=lr), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
  history = cifar_model.fit(x_train, y_train, batch_size=128, epochs=25, validation_data=(x_test, y_test))
  adam_histories.append(history)
  # RMSprop
  cifar_model.compile(optimizer=optimizers.RMSprop(learning_rate=lr), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
  history = cifar_model.fit(x_train, y_train, batch_size=128, epochs=25, validation_data=(x_test, y_test))
  rmsprop_histories.append(history)
# Out:
# /usr/local/lib/python3.9/dist-packages/keras/initializers/initializers_v2.py:120: UserWarning: The initializer GlorotUniform is unseeded and being called multiple times, which will return identical values  each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initalizer instance more than once.
#   warnings.warn(
# Epoch 1/25
# 391/391 [==============================] - 5s 9ms/step - loss: 2.3029 - accuracy: 0.1005 - val_loss: 2.3025 - val_accuracy: 0.1003
# Epoch 2/25
# 391/391 [==============================] - 4s 9ms/step - loss: 2.3020 - accuracy: 0.1007 - val_loss: 2.3017 - val_accuracy: 0.1010
# Epoch 3/25
# 391/391 [==============================] - 3s 8ms/step - loss: 2.3012 - accuracy: 0.1018 - val_loss: 2.3009 - val_accuracy: 0.1014
# Epoch 4/25
# 391/391 [==============================] - 3s 8ms/step - loss: 2.3004 - accuracy: 0.1016 - val_loss: 2.3001 - val_accuracy: 0.1017
# Epoch 5/25
# 391/391 [==============================] - 3s 8ms/step - loss: 2.2996 - accuracy: 0.1019 - val_loss: 2.2991 - val_accuracy: 0.1022
# Epoch 6/25
# 391/391 [==============================] - 4s 9ms/step - loss: 2.2985 - accuracy: 0.1033 - val_loss: 2.2979 - val_accuracy: 0.1033
# Epoch 7/25
# 391/391 [==============================] - 3s 7ms/step - loss: 2.2972 - accuracy: 0.1041 - val_loss: 2.2964 - val_accuracy: 0.1041
# Epoch 8/25
# 391/391 [==============================] - 3s 8ms/step - loss: 2.
25
# 391/391 [==============================] - 3s 8ms/step - loss: 0.6671 - accuracy: 0.7696 - val_loss: 0.9040 - val_accuracy: 0.6910
# Epoch 10/25
# 391/391 [==============================] - 4s 9ms/step - loss: 0.6486 - accuracy: 0.7753 - val_loss: 0.9708 - val_accuracy: 0.6717
# Epoch 11/25
# 391/391 [==============================] - 3s 8ms/step - loss: 0.6351 - accuracy: 0.7814 - val_loss: 0.9302 - val_accuracy: 0.6883
# Epoch 12/25
# 391/391 [==============================] - 3s 8ms/step - loss: 0.6213 - accuracy: 0.7855 - val_loss: 0.9338 - val_accuracy: 0.6905
# Epoch 13/25
# 391/391 [==============================] - 3s 8ms/step - loss: 0.6055 - accuracy: 0.7916 - val_loss: 0.9384 - val_accuracy: 0.6959
# Epoch 14/25
# 391/391 [==============================] - 4s 9ms/step - loss: 0.5901 - accuracy: 0.7971 - val_loss: 0.9594 - val_accuracy: 0.6823
# Epoch 15/25
# 391/391 [==============================] - 3s 8ms/step - loss: 0.5771 - accuracy: 0.8002 - val_loss: 1.0053 - val_accuracy: 0.6722
# Epoch 16/25
# 391/391 [==============================] - 3s 8ms/step - loss: 0.5573 - accuracy: 0.8085 - val_loss: 0.9431 - val_accuracy: 0.6955
# Epoch 17/25
# 391/391 [==============================] - 3s 8ms/step - loss: 0.5462 - accuracy: 0.8129 - val_loss: 0.9914 - val_accuracy: 0.6785
# Epoch 18/25
# 391/391 [==============================] - 3s 9ms/step - loss: 0.5314 - accuracy: 0.8173 - val_loss: 0.9485 - val_accuracy: 0.6915
# Epoch 19/25
# 391/391 [==============================] - 3s 8ms/step - loss: 0.5156 - accuracy: 0.8217 - val_loss: 0.9878 - val_accuracy: 0.6885
# Epoch 20/25
# 391/391 [==============================] - 3s 8ms/step - loss: 0.5000 - accuracy: 0.8277 - val_loss: 0.9573 - val_accuracy: 0.6988
# Epoch 21/25
# 391/391 [==============================] - 3s 9ms/step - loss: 0.4857 - accuracy: 0.8324 - val_loss: 0.9497 - val_accuracy: 0.6997
# Epoch 22/25
# 391/391 [==============================] - 3s 8ms/step - loss: 0.4703 - accuracy: 0.8382 - val_loss: 0.9761 - val_accuracy: 0.6959
# Epoch 23/25
# 391/391 [==============================] - 3s 8ms/step - loss: 0.4560 - accuracy: 0.8446 - val_loss: 1.0171 - val_accuracy: 0.6845
# Epoch 24/25
# 391/391 [==============================] - 3s 8ms/step - loss: 0.4433 - accuracy: 0.8481 - val_loss: 1.0063 - val_accuracy: 0.6949
# Epoch 25/25
# 391/391 [==============================] - 4s 9ms/step - loss: 0.4296 - accuracy: 0.8531 - val_loss: 1.0234 - val_accuracy: 0.6879

# %%
### Create plots that show the losses and metrics for each of these runs, and
### comment on the results in your report.
# Plot the training accuracy vs. learning rate for each optimizer
plt.figure(figsize=(12, 8))
plt.semilogx(learning_rates, [h.history['loss'][-1] for h in sgd_histories], 'o-', label='SGD')
plt.semilogx(learning_rates, [h.history['loss'][-1] for h in adam_histories], 'o-', label='Adam')
plt.semilogx(learning_rates, [h.history['loss'][-1] for h in rmsprop_histories], 'o-', label='RMSprop')
plt.xlabel('Learning Rate')
plt.ylabel('Training Loss')
plt.legend()
plt.show()

# Plot the validation accuracy vs. learning rate for each optimizer
plt.figure(figsize=(12, 8))
plt.semilogx(learning_rates, [h.history['val_loss'][-1] for h in sgd_histories], 'o-', label='SGD')
plt.semilogx(learning_rates, [h.history['val_loss'][-1] for h in adam_histories], 'o-', label='Adam')
plt.semilogx(learning_rates, [h.history['val_loss'][-1] for h in rmsprop_histories], 'o-', label='RMSprop')
plt.xlabel('Learning Rate')
plt.ylabel('Validation Loss')
plt.legend()
plt.show()

# %% [markdown]
# # Task 3 - Testing Batch Sizes
#
# The batch size can heavily influence the amount of time it takes to train a model. Vary the batch size used to train the model and, utilising the Early Stopping callback provided, create plots that show how the time per epoch and total training time changes.
#
# Comment on these results in your report—consider both how the batch size influences the number of epochs it takes to reach a solution, and how long each epoch takes to run. Why is this the case?

# %%
### Train the model with a range of different batch sizes, resetting the weights
### each time. Use an Early Stopping callback to prevent the model training for
### too long.

# define list of batch sizes to try
batch_sizes = [16, 32, 64, 128, 256]
val_losses = []

# loop through batch sizes and train model
for batch_size in batch_sizes:
    reinitialize(cifar_model)
    print(f"Training with batch size {batch_size}...")
    model = cifar_model
    model.compile(optimizer=optimizers.SGD(), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    Early_Stop = callbacks.EarlyStopping(monitor='val_loss', patience=3)
    history = model.fit(x_train, y_train, batch_size=batch_size, epochs=50, validation_data=(x_test, y_test), callbacks=[Early_Stop])
    val_losses.append(history.history['val_loss'][-1])

# plot validation losses for each batch size
plt.plot(batch_sizes, val_losses, '-o')
plt.xlabel('Batch Size')
plt.ylabel('Validation Loss')
plt.title('Validation Loss vs. Batch Size')
plt.show()

# print best batch size
best_batch_size = batch_sizes[val_losses.index(min(val_losses))]
print(f"Best batch size: {best_batch_size}")
# Out:
# /usr/local/lib/python3.9/dist-packages/keras/initializers/initializers_v2.py:120: UserWarning: The initializer GlorotUniform is unseeded and being called multiple times, which will return identical values  each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initalizer instance more than once.
#   warnings.warn(
# Training with batch size 16...
# Epoch 1/50
# 3125/3125 [==============================] - 22s 7ms/step - loss: 1.8927 - accuracy: 0.3060 - val_loss: 1.5238 - val_accuracy: 0.4512
# Epoch 2/50
# 3125/3125 [==============================] - 21s 7ms/step - loss: 1.4512 - accuracy: 0.4781 - val_loss: 1.3322 - val_accuracy: 0.5201
# Epoch 3/50
# 3125/3125 [==============================] - 19s 6ms/step - loss: 1.2699 - accuracy: 0.5468 - val_loss: 1.1854 - val_accuracy: 0.5809
# Epoch 4/50
# 3125/3125 [==============================] - 21s 7ms/step - loss: 1.1374 - accuracy: 0.5964 - val_loss: 1.1425 - val_accuracy: 0.6003
# Epoch 5/50
# 3125/3125 [==============================] - 20s 7ms/step - loss: 1.0313 - accuracy: 0.6339 - val_loss: 1.0756 - val_accuracy: 0.6196
# Epoch 6/50
# 3125/3125 [==============================] - 20s 6ms/step - loss: 0.9379 - accuracy: 0.6714 - val_loss: 1.1304 - val_accuracy: 0.6101
# Epoch 7/50
# 3125/3125 [==============================] - 20s 7ms/step - loss: 0.8567 - accuracy: 0.6992 - val_loss: 1.0085 - val_accuracy: 0.6467
# Epoch 8/50
# 3125/3125 [==============================] - 19s 6ms/step - loss: 0.7749 - accuracy: 0.7281 - val_loss: 0.9846 - val_accuracy: 0.6602
# Epoch 9/50
# 3125/3125 [==============================] - 21s 7ms/step - loss: 0.6958 - accuracy: 0.7588 - val_loss: 1.0337 - val_accuracy: 0.6582
# Epoch 10/50
# 3125/3125 [==============================] - 21s 7ms/step - loss: 0.6207 - accuracy: 0.7834 - val_loss: 1.0631 - val_accuracy: 0.6560
# Epoch 11/50
# 3125/3125 [==============================] - 19s 6ms/step - loss: 0.5444 - accuracy: 0.8082 - val_loss: 1.0531 - val_accuracy: 0.6685
# Training with batch size 32...
# Epoch 1/50
# 1563/1563 [==============================] - 12s 7ms/step - loss: 2.0766 - accuracy: 0.2398 - val_loss: 1.7512 - val_accuracy: 0.3731
# Epoch 2/50
# 1563/1563 [==============================] - 11s 7ms/step - loss: 1
# 782/782 [==============================] - 5s 7ms/step - loss: 1.2601 - accuracy: 0.5533 - val_loss: 1.3922 - val_accuracy: 0.5057
# Epoch 8/50
# 782/782 [==============================] - 6s 8ms/step - loss: 1.2073 - accuracy: 0.5738 - val_loss: 1.3010 - val_accuracy: 0.5352
# Epoch 9/50
# 782/782 [==============================] - 5s 7ms/step - loss: 1.1537 - accuracy: 0.5926 - val_loss: 1.8091 - val_accuracy: 0.4494
# Epoch 10/50
# 782/782 [==============================] - 6s 7ms/step - loss: 1.1053 - accuracy: 0.6106 - val_loss: 1.1519 - val_accuracy: 0.5979
# Epoch 11/50
# 782/782 [==============================] - 5s 7ms/step - loss: 1.0573 - accuracy: 0.6274 - val_loss: 1.3085 - val_accuracy: 0.5480
# Epoch 12/50
# 782/782 [==============================] - 5s 7ms/step - loss: 1.0112 - accuracy: 0.6452 - val_loss: 1.2432 - val_accuracy: 0.5611
# Epoch 13/50
# 782/782 [==============================] - 6s 7ms/step - loss: 0.9715 - accuracy: 0.6580 - val_loss: 1.1897 - val_accuracy: 0.5866
# Training with batch size 128...
# Epoch 1/50
# 391/391 [==============================] - 5s 9ms/step - loss: 2.2928 - accuracy: 0.1258 - val_loss: 2.2685 - val_accuracy: 0.1115
# Epoch 2/50
# 391/391 [==============================] - 3s 9ms/step - loss: 2.1390 - accuracy: 0.2162 - val_loss: 2.2402 - val_accuracy: 0.1790
# Epoch 3/50
# 391/391 [==============================] - 3s 8ms/step - loss: 1.9114 - accuracy: 0.3170 - val_loss: 1.8151 - val_accuracy: 0.3527
# Epoch 4/50
# 391/391 [==============================] - 3s 8ms/step - loss: 1.7470 - accuracy: 0.3781 - val_loss: 1.6460 - val_accuracy: 0.4128
# Epoch 5/50
# 391/391 [==============================] - 3s 8ms/step - loss: 1.6190 - accuracy: 0.4243 - val_loss: 1.5641 - val_accuracy: 0.4392
# Epoch 6/50
# 391/391 [==============================] - 3s 9ms/step - loss: 1.5309 - accuracy: 0.4544 - val_loss: 1.5802 - val_accuracy: 0.4386
# Epoch 7/50
# 391/391 [==============================] - 3s 8ms/step - loss: 1.4633 - accuracy: 0.4789 - val_loss: 1.4194 - val_accuracy: 0.4933
# Epoch 8/50
# 391/391 [==============================] - 3s 8ms/step - loss: 1.4096 - accuracy: 0.5008 - val_loss: 1.4302 - val_accuracy: 0.4870
# Epoch 9/50
# 391/391 [==============================] - 3s 9ms/step - loss: 1.3642 - accuracy: 0.5176 - val_loss: 1.3678 - val_accuracy: 0.5128
# Epoch 10/50
# 391/391 [==============================] - 3s 8ms/step - loss: 1.3226 - accuracy: 0.5331 - val_loss: 1.3293 - val_accuracy: 0.5247
# Epoch 11/50
# 391/391 [==============================] - 3s 8ms/step - loss: 1.2869 - accuracy: 0.5467 - val_loss: 1.3027 - val_accuracy: 0.5392
# Epoch 12/50
# 391/391 [==============================] - 3s 8ms/step - loss: 1.2525 - accuracy: 0.5558 - val_loss: 1.3139 - val_accuracy: 0.5356
# Epoch 13/50
# 391/391 [==============================] - 3s 9ms/step - loss: 1.2151 - accuracy: 0.5715 - val_loss: 1.2968 - val_accuracy: 0.5426
# Epoch 14/50
# 391/391 [==============================] - 3s 8ms/step - loss: 1.1864 - accuracy: 0.5819 - val_loss: 1.2167 - val_accuracy: 0.5677
# Epoch 15/50
# 391/391 [==============================] - 3s 8ms/step - loss: 1.1561 - accuracy: 0.5951 - val_loss: 1.2459 - val_accuracy: 0.5632
# Epoch 16/50
# 391/391 [==============================] - 3s 8ms/step - loss: 1.1265 - accuracy: 0.6040 - val_loss: 1.2708 - val_accuracy: 0.5475
# Epoch 17/50
# 391/391 [==============================] - 3s 8ms/step - loss: 1.0958 - accuracy: 0.6150 - val_loss: 1.1971 - val_accuracy: 0.5777
# Epoch 18/50
# 391/391 [==============================] - 3s 8ms/step - loss: 1.0655 - accuracy: 0.6270 - val_loss: 1.1596 - val_accuracy: 0.5890
# Epoch 19/50
# 391/391 [==============================] - 3s 8ms/step - loss: 1.0412 - accuracy: 0.6348 - val_loss: 1.1714 - val_accuracy: 0.5847
# Epoch 20/50
# 391/391 [==============================] - 3s 9ms/step - loss: 1.0160 - accuracy: 0.6455 - val_loss: 1.1815 - val_accuracy: 0.5855
# Epoch 21/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.9869 - accuracy: 0.6550 - val_loss: 1.1207 - val_accuracy: 0.6035
# Epoch 22/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.9605 - accuracy: 0.6643 - val_loss: 1.1536 - val_accuracy: 0.6022
# Epoch 23/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.9383 - accuracy: 0.6726 - val_loss: 1.1208 - val_accuracy: 0.6057
# Epoch 24/50
# 391/391 [==============================] - 3s 9ms/step - loss: 0.9129 - accuracy: 0.6835 - val_loss: 1.2065 - val_accuracy: 0.5876
# Training with batch size 256...
# Epoch 1/50
# 196/196 [==============================] - 4s 17ms/step - loss: 2.3001 - accuracy: 0.1171 - val_loss: 2.2951 - val_accuracy: 0.1076
# Epoch 2/50
# 196/196 [==============================] - 3s 14ms/step - loss: 2.2853 - accuracy: 0.1106 - val_loss: 2.2675 - val_accuracy: 0.1283
# Epoch 3/50
# 196/196 [==============================] - 3s 13ms/step - loss: 2.2060 - accuracy: 0.1790 - val_loss: 2.1779 - val_accuracy: 0.1839
# Epoch 4/50
# 196/196 [==============================] - 3s 13ms/step - loss: 2.0596 - accuracy: 0.2627 - val_loss: 1.9833 - val_accuracy: 0.2992
# Epoch 5/50
# 196/196 [==============================] - 2s 13ms/step - loss: 1.9496 - accuracy: 0.3076 - val_loss: 1.9698 - val_accuracy: 0.3370
# Epoch 6/50
# 196/196 [==============================] - 3s 14ms/step - loss: 1.8477 - accuracy: 0.3419 - val_loss: 1.9110 - val_accuracy: 0.3356
# Epoch 7/50
# 196/196 [==============================] - 2s 13ms/step - loss: 1.7573 - accuracy: 0.3776 - val_loss: 1.8561 - val_accuracy: 0.3557
# Epoch 8/50
# 196/196 [==============================] - 3s 14ms/step - loss: 1.6815 - accuracy: 0.4033 - val_loss: 1.5995 - val_accuracy: 0.4284
# Epoch 9/50
# 196/196 [==============================] - 3s 13ms/step - loss: 1.6168 - accuracy: 0.4281 - val_loss: 1.6918 - val_accuracy: 0.3956
# Epoch 10/50
# 196/196 [==============================] - 3s 13ms/step - loss: 1.5711 - accuracy: 0.4429 - val_loss: 1.5477 - val_accuracy: 0.4449
# Epoch 11/50
# 196/196 [==============================] - 3s 13ms/step - loss: 1.5277 - accuracy: 0.4583 - val_loss: 1.5478 - val_accuracy: 0.4494
# Epoch 12/50
# 196/196 [==============================] - 3s 13ms/step - loss: 1.4875 - accuracy: 0.4731 - val_loss: 1.5389 - val_accuracy: 0.4327
# Epoch 13/50
# 196/196 [==============================] - 3s 14ms/step - loss: 1.4492 - accuracy: 0.4873 - val_loss: 1.4483 - val_accuracy: 0.4805
# Epoch 14/50
# 196/196 [==============================] - 3s 13ms/step - loss: 1.4169 - accuracy: 0.4984 - val_loss: 1.5343 - val_accuracy: 0.4477
# Epoch 15/50
# 196/196 [==============================] - 3s 14ms/step - loss: 1.3945 - accuracy: 0.5094 - val_loss: 1.4325 - val_accuracy: 0.4914
# Epoch 16/50
# 196/196 [==============================] - 3s 13ms/step - loss: 1.3678 - accuracy: 0.5165 - val_loss: 1.4145 - val_accuracy: 0.5023
# Epoch 17/50
# 196/196 [==============================] - 2s 13ms/step - loss: 1.3500 - accuracy: 0.5227 - val_loss: 1.4334 - val_accuracy: 0.4945
# Epoch 18/50
# 196/196 [==============================] - 2s 13ms/step - loss: 1.3233 - accuracy: 0.5328 - val_loss: 1.4004 - val_accuracy: 0.5023
# Epoch 19/50
# 196/196 [==============================] - 3s 14ms/step - loss: 1.3043 - accuracy: 0.5401 - val_loss: 1.3661 - val_accuracy: 0.5185
# Epoch 20/50
# 196/196 [==============================] - 3s 13ms/step - loss: 1.2760 - accuracy: 0.5512 - val_loss: 1.3177 - val_accuracy: 0.5323
# Epoch 21/50
# 196/196 [==============================] - 3s 14ms/step - loss: 1.2611 - accuracy: 0.5569 - val_loss: 1.3380 - val_accuracy: 0.5268
# Epoch 22/50
# 196/196 [==============================] - 2s 13ms/step - loss: 1.2416 - accuracy: 0.5631 - val_loss: 1.3324 - val_accuracy: 0.5200
# Epoch 23/50
# 196/196 [==============================] - 3s 13ms/step - loss: 1.2197 - accuracy: 0.5702 - val_loss: 1.3126 - val_accuracy: 0.5279
# Epoch 24/50
# 196/196 [==============================] - 3s 14ms/step - loss: 1.2000 - accuracy: 0.5777 - val_loss: 1.5697 - val_accuracy: 0.4698
# Epoch 25/50
# 196/196 [==============================] - 3s 13ms/step - loss: 1.1935 - accuracy: 0.5824 - val_loss: 1.3381 - val_accuracy: 0.5247
# Epoch 26/50
# 196/196 [==============================] - 3s 13ms/step - loss: 1.1688 - accuracy: 0.5868 - val_loss: 1.3532 - val_accuracy: 0.5249
# Best batch size: 16

# %% [markdown]
# # Task 4 - Adding Regularisation
#
# The model as provided does not contain any regularisation techniques. Edit the model architecture to include at least two examples of regularisation. Retrain the model using the new architecture, and repeat the analysis performed in task 1.
#
# In your report, compare and contrast the results from this task, with those from the initial model configuration. Explain HOW and WHY the results are different, with consideration to the predicted classifications, losses and metrics.

# %%
### Update the model architecture to include at least two types of regularization.
### Train the model using the ideal settings found in previous tasks.
inputs = layers.Input(shape=(32, 32, 3), name='Input')
cov1 = layers.Conv2D(16, 3, padding='same', activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(inputs)
drop1 = layers.Dropout(0.3)(cov1)
cov2 = layers.Conv2D(16, 3, padding='same', activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(drop1)
max1 = layers.MaxPooling2D()(cov2)
cov3 = layers.Conv2D(32, 3, padding='same', activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(max1)
drop2 =layers.Dropout(0.4)(cov3)
cov4 = layers.Conv2D(32, 3, padding='same', activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(drop2)
max2 = layers.MaxPooling2D()(cov4)
cov5 = layers.Conv2D(64, 3, padding='same', activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(max2)
drop3 = layers.Dropout(0.5)(cov5)
cov6 = layers.Conv2D(64, 3, padding='same', activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(drop3)
max3 = layers.MaxPooling2D()(cov6)
flatten = layers.Flatten()(max3)
dens = layers.Dense(512, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(flatten)
outputs = layers.Dense(10, activation='softmax')(dens)

model = tf.keras.Model(inputs=inputs, outputs=outputs, name='cifar_model_1')

# %%
### Repeat your analysis from task 1, creating plots of the losses, metrics AND
### predicted classifications of images in the test set.
reinitialize(model)
reinitialize(cifar_model)
model.compile(optimizer=optimizers.SGD(), loss='sparse_categorical_crossentropy', 
              metrics=['accuracy'])

history_1 = model.fit(x_train, y_train, batch_size=128, epochs=50, 
                      validation_data=(x_test, y_test))

# Plot loss and validation loss
plt.figure()
plt.plot(history_1.history['loss'], label='Training Loss')
plt.plot(history_1.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# Plot accuracy and validation accuracy
plt.figure()
plt.plot(history_1.history['accuracy'], label='Training Accuracy')
plt.plot(history_1.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Get predicted classifications of test set images
y_pred = model.predict(x_test)
y_pred_classes = np.argmax(y_pred, axis=1)

# Plot sample of test set images and their predicted classifications
fig, axs = plt.subplots(5, 5, figsize=(10, 10))
fig.suptitle('Sample of Test Set Images and Predicted Classifications')
for i in range(5):
    for j in range(5):
        index = i * 5 + j
        axs[i, j].imshow(x_test[index])
        axs[i, j].set_title(f"Predicted: {class_names[y_pred_classes[index]]}")
        axs[i, j].axis('off')
plt.show()
# Out:
# /usr/local/lib/python3.9/dist-packages/keras/initializers/initializers_v2.py:120: UserWarning: The initializer GlorotUniform is unseeded and being called multiple times, which will return identical values  each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initalizer instance more than once.
#   warnings.warn(
# Epoch 1
50
# 391/391 [==============================] - 4s 11ms/step - loss: 1.9908 - accuracy: 0.4558 - val_loss: 1.9560 - val_accuracy: 0.4657
# Epoch 23/50
# 391/391 [==============================] - 5s 12ms/step - loss: 1.9435 - accuracy: 0.4612 - val_loss: 1.9177 - val_accuracy: 0.4750
# Epoch 24/50
# 391/391 [==============================] - 4s 11ms/step - loss: 1.8984 - accuracy: 0.4656 - val_loss: 1.8441 - val_accuracy: 0.4837
# Epoch 25/50
# 391/391 [==============================] - 4s 10ms/step - loss: 1.8622 - accuracy: 0.4680 - val_loss: 1.8124 - val_accuracy: 0.4838
# Epoch 26/50
# 391/391 [==============================] - 5s 14ms/step - loss: 1.8254 - accuracy: 0.4726 - val_loss: 1.8108 - val_accuracy: 0.4682
# Epoch 27/50
# 391/391 [==============================] - 4s 10ms/step - loss: 1.8014 - accuracy: 0.4740 - val_loss: 1.8304 - val_accuracy: 0.4790
# Epoch 28/50
# 391/391 [==============================] - 4s 10ms/step - loss: 1.7789 - accuracy: 0.4788 - val_loss: 1.7393 - val_accuracy: 0.4973
# Epoch 29/50
# 391/391 [==============================] - 4s 11ms/step - loss: 1.7522 - accuracy: 0.4832 - val_loss: 1.7625 - val_accuracy: 0.4838
# Epoch 30/50
# 391/391 [==============================] - 4s 10ms/step - loss: 1.7346 - accuracy: 0.4829 - val_loss: 1.6953 - val_accuracy: 0.5017
# Epoch 31/50
# 391/391 [==============================] - 4s 10ms/step - loss: 1.7199 - accuracy: 0.4880 - val_loss: 1.6868 - val_accuracy: 0.5032
# Epoch 32/50
# 391/391 [==============================] - 4s 11ms/step - loss: 1.7010 - accuracy: 0.4897 - val_loss: 1.6920 - val_accuracy: 0.4977
# Epoch 33/50
# 391/391 [==============================] - 4s 10ms/step - loss: 1.6875 - accuracy: 0.4945 - val_loss: 1.6420 - val_accuracy: 0.5156
# Epoch 34/50
# 391/391 [==============================] - 4s 10ms/step - loss: 1.6773 - accuracy: 0.4966 - val_loss: 1.6625 - val_accuracy: 0.5099
# Epoch 35/50
# 391/391 [==============================] - 4s 11ms/step - loss: 1.6643 - accuracy: 0.4997 - val_loss: 1.7827 - val_accuracy: 0.4643
# Epoch 36/50
# 391/391 [==============================] - 4s 10ms/step - loss: 1.6622 - accuracy: 0.5002 - val_loss: 1.6447 - val_accuracy: 0.5020
# Epoch 37/50
# 391/391 [==============================] - 4s 10ms/step - loss: 1.6497 - accuracy: 0.5017 - val_loss: 1.6206 - val_accuracy: 0.5164
# Epoch 38/50
# 391/391 [==============================] - 4s 11ms/step - loss: 1.6400 - accuracy: 0.5060 - val_loss: 1.6262 - val_accuracy: 0.5120
# Epoch 39/50
# 391/391 [==============================] - 4s 10ms/step - loss: 1.6257 - accuracy: 0.5089 - val_loss: 1.6396 - val_accuracy: 0.5084
# Epoch 40/50
# 391/391 [==============================] - 4s 10ms/step - loss: 1.6262 - accuracy: 0.5105 - val_loss: 1.7006 - val_accuracy: 0.4871
# Epoch 41/50
# 391/391 [==============================] - 4s 11ms/step - loss: 1.6199 - accuracy: 0.5106 - val_loss: 1.6331 - val_accuracy: 0.5112
# Epoch 42/50
# 391/391 [==============================] - 4s 10ms/step - loss: 1.6151 - accuracy: 0.5160 - val_loss: 1.6388 - val_accuracy: 0.5032
# Epoch 43/50
# 391/391 [==============================] - 4s 10ms/step - loss: 1.6098 - accuracy: 0.5180 - val_loss: 1.6360 - val_accuracy: 0.5093
# Epoch 44/50
# 391/391 [==============================] - 4s 11ms/step - loss: 1.6078 - accuracy: 0.5188 - val_loss: 1.6153 - val_accuracy: 0.5157
# Epoch 45/50
# 391/391 [==============================] - 4s 10ms/step - loss: 1.5988 - accuracy: 0.5242 - val_loss: 1.7046 - val_accuracy: 0.4857
# Epoch 46/50
# 391/391 [==============================] - 4s 10ms/step - loss: 1.5977 - accuracy: 0.5228 - val_loss: 1.6194 - val_accuracy: 0.5204
# Epoch 47/50
# 391/391 [==============================] - 4s 11ms/step - loss: 1.5915 - accuracy: 0.5245 - val_loss: 1.5990 - val_accuracy: 0.5267
# Epoch 48/50
# 391/391 [==============================] - 4s 10ms/step - loss: 1.5875 - accuracy: 0.5284 - val_loss: 1.5829 - val_accuracy: 0.5300
# Epoch 49/50
# 391/391 [==============================] - 4s 10ms/step - loss: 1.5820 - accuracy: 0.5312 - val_loss: 1.5856 - val_accuracy: 0.5256
# Epoch 50/50
# 391/391 [==============================] - 4s 11ms/step - loss: 1.5824 - accuracy: 0.5329 - val_loss: 1.7337 - val_accuracy: 0.4857
# 313/313 [==============================] - 1s 3ms/step
